# %%
import matplotlib.pyplot as plt

# %%
f = open("C:\\Windows\\Temp\\log1.txt").readlines()

# %%
len(f)
# Out:
# 745866

# %%
f[:100]
# Out:
# ['Servicing hardware INT=0x20\n',
#  '     0: v=20 e=0000 i=0 cpl=0 IP=0038:000000003e9dbe4a pc=000000003e9dbe4a SP=0030:000000003fe71b90 env->regs[R_EAX]=800000000000000e\n',
#  'RAX=800000000000000e RBX=000000003e9df218 RCX=0000000000000000 RDX=0000000000000000\n',
#  'RSI=0000000000000000 RDI=0000000000000003 RBP=0000000000000003 RSP=000000003fe71b90\n',
#  'R8 =000000000000e700 R9 =0000000000000000 R10=0000000000000000 R11=000000003f4e7ba8\n',
#  'R12=0000000000000000 R13=000000003fe71cb8 R14=8000000000000000 R15=0000000000000000\n',
#  'RIP=000000003e9dbe4a RFL=00000202 [-------] CPL=0 II=0 A20=1 SMM=0 HLT=0\n',
#  'ES =0030 0000000000000000 ffffffff 00cf9300 DPL=0 DS   [-WA]\n',
#  'CS =0038 0000000000000000 ffffffff 00af9a00 DPL=0 CS64 [-R-]\n',
#  'SS =0030 0000000000000000 ffffffff 00cf9300 DPL=0 DS   [-WA]\n',
#  'DS =0030 0000000000000000 ffffffff 00cf9300 DPL=0 DS   [-WA]\n',
#  'FS =0030 0000000000000000 ffffffff 00cf9300 DPL=0 DS   [-WA]\n',
# ...

# %%
arr = []
for i in f[:]:
    if i[:4] == "RIP=":
        #print(i)
        arr.append(int(i[4:20], 16))

# %%
for i in arr:
    print(hex(i))
# Out:
# 0x3e9dbe4a
# 0x3e9d6f90
# 0x3ec51ee3
# 0x3ec54e30
# 0x3ec568a3

# %%
plt.hist(arr, 100);

# %%
plt.plot(arr)

# %%
f2 = open("C:\\Windows\\Temp\\log.txt").readlines()

# %%
arr = []
for i in f2[:]:
    if i[:4] == "RIP=":
        #print(i)
        arr.append(int(i[4:20], 16))

# %%
for k in sorted(arr):
    print(hex(k))
# Out:
# 0x0
# 0x3ea
# 0xbba
# 0x17d0
# 0x2000
# 0x27d0
# 0x37d0
# 0x37d0
# 0x43e8
# 0x47d0
# 0x5000
# 0x57d0
# 0x5fa0
# 0x67d0
# 0x7000
# 0x7bb8
# 0x83e8
# 0x9000
# 0x97d0
# 0xa3e8
# 0xabb8
# 0xb7d0
# 0xc3e8
# 0xcbb8
# 0xd7d0
# 0xe000
# 0xebb8
# 0xf3e8
# 0x10000
# 0x107d0
# 0x113e8
# 0x11fa0
# 0x12bb8
# 0x137d0
# 0x143e8
# 0x14bb8
# 0x157d0
# 0x16000
# 0x167d0
# 0x173e8
# 0x17fa0
# 0x187d0
# 0x193e8
# 0x19bb8
# 0x1a7d0
# 0x1b3e8
# 0x1bfa0
# 0x1c7d0
# 0x1d000
# 0x1dbb8
# 0x1e7d0
# 0x1f000
# 0x1fbb8
# 0x207d0
# 0x21000
# 0x21bb8
# 0x227d0
# 0x237d0
# 0x243e8
# 0x24bb8
# 0x253e8
# 0x25fa0
# 0x263e8
# 0x26fa0
# 0x277d0
# 0x28000
# 0x283e8
# 0x28fa0
# 0x297d0
# 0x2a000
# 0x2abb8
# 0x2b3e8
# 0x2bfa0
# 0x2c7d0
# 0x2d3e8
# 0x2dbb8
# 0x2e7d0
# 0x2f3e8
# 0x2fbb8
# 0x307d0
# 0x31000
# 0x317d0
# 0x323e8
# 0x323e8
# 0x32bb8
# 0x333e8
# 0x33bb8
# 0x343e8
# 0x34fa0
# 0x353e8
# 0x35bb8
# 0x363e8
# 0x36bb8
# 0x377d0
# 0x38000
# 0x38bb8
# 0x393e8
# 0x3a000
# 0x3abb8
# 0x3b3e8
# 0x3bbb8
# 0x3c3e8
# 0x3cbb8
# ...

# %%
plt.hist(arr, 100);

# %%
plt.plot(arr)
